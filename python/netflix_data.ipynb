# %%
netflix subscription dataset from 2021 to 2023

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %%
#import dataset
net = pd.read_csv(r"C:\Users\hp\OneDrive\vickNetflix data.csv")

# %%
#view data
net
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0   15-01-22         10/6/2023
# 1         2.0           Premium             15.0   5/9/2021          22-06-23
# 2         3.0          Standard             12.0   28-02-23          27-06-23
# 3         4.0          Standard             12.0  10/7/2022          26-06-23
# 4         5.0             Basic             10.0   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2519      NaN               NaN              NaN        NaN               NaN
# 2520      NaN               NaN              NaN        NaN               NaN
# 2521      NaN               NaN              NaN        NaN               NaN
# 2522      NaN               NaN              NaN        NaN               NaN
# 2523      NaN               NaN              NaN        NaN               NaN
#
# ...

# %%
getting to know the dataset
data wrangling

# %%
#the head function
net.head()
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0      1.0             Basic             10.0   15-01-22         10/6/2023
# 1      2.0           Premium             15.0   5/9/2021          22-06-23
# 2      3.0          Standard             12.0   28-02-23          27-06-23
# 3      4.0          Standard             12.0  10/7/2022          26-06-23
# 4      5.0             Basic             10.0   1/5/2023          28-06-23
#
#           Country   Age  Gender      Device Plan Duration       not usefull
# 0   United States  28.0    Male  Smartphone       1 Month   BasicSmartphone
# 1          Canada  35.0  Female      Tablet       1 Month     PremiumTablet
# 2  United Kingdom  42.0    Male    Smart TV       1 Month  StandardSmart TV
# 3       Australia  51.0  Female      Laptop       1 Month    StandardLaptop
# 4         Germany  33.0    Male  Smartphone       1 Month   BasicSmartphone

# %%
#the tail function
net.tail()
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2519      NaN               NaN              NaN       NaN               NaN
# 2520      NaN               NaN              NaN       NaN               NaN
# 2521      NaN               NaN              NaN       NaN               NaN
# 2522      NaN               NaN              NaN       NaN               NaN
# 2523      NaN               NaN              NaN       NaN               NaN
#
#      Country  Age Gender Device Plan Duration not usefull
# 2519     NaN  NaN    NaN    NaN           NaN         NaN
# 2520     NaN  NaN    NaN    NaN           NaN         NaN
# 2521     NaN  NaN    NaN    NaN           NaN         NaN
# 2522     NaN  NaN    NaN    NaN           NaN         NaN
# 2523     NaN  NaN    NaN    NaN           NaN         NaN

# %%
# the shape function shows the dimensions of data structures, that is the quality of rows and columns present in the dataframe
net.shape
# Out:
# (2524, 11)

# %%
#the size function shows the the size of the data
net.size
# Out:
# 27764

# %%
#this shows the column names
net.columns
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration', 'not usefull'],
#       dtype='object')

# %%
#datatypes
net.dtypes
# Out:
# User ID              float64
# Subscription Type     object
# Monthly Revenue      float64
# Join Date             object
# Last Payment Date     object
# Country               object
# Age                  float64
# Gender                object
# Device                object
# Plan Duration         object
# not usefull           object
# dtype: object

# %%
#the info function
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2502 non-null   float64
#  1   Subscription Type  2502 non-null   object
#  2   Monthly Revenue    2500 non-null   float64
#  3   Join Date          2502 non-null   object
#  4   Last Payment Date  2502 non-null   object
#  5   Country            2502 non-null   object
#  6   Age                2501 non-null   float64
#  7   Gender             2501 non-null   object
#  8   Device             2501 non-null   object
#  9   Plan Duration      2501 non-null   object
#  10  not usefull        2483 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 217.0+ KB

# %%
Data cleaning

Finding the duplicate records and null values

# %%
net.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2519     True
# 2520     True
# 2521     True
# 2522     True
# 2523     True
# Length: 2524, dtype: bool

# %%
 this function only returned the top 5 rows and the bottom 5 rows, hence not given us the entired dataset

# %%
net[net.duplicated()]
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2478   2478.0          Standard             10.0  16-08-22          13-07-23
# 2504      NaN               NaN              NaN       NaN               NaN
# 2505      NaN               NaN              NaN       NaN               NaN
# 2506      NaN               NaN              NaN       NaN               NaN
# 2507      NaN               NaN              NaN       NaN               NaN
# 2508      NaN               NaN              NaN       NaN               NaN
# 2509      NaN               NaN              NaN       NaN               NaN
# 2510      NaN               NaN              NaN       NaN               NaN
# 2511      NaN               NaN              NaN       NaN               NaN
# 2512      NaN               NaN              NaN       NaN               NaN
# 2513      NaN               NaN              NaN       NaN               NaN
# ...

# %%
they are over 20 duplicates found in the dataset

# %%
net.drop_duplicates(inplace = True)

# %%
verify that duplicate values have been removed

# %%
net.shape
# Out:
# (2503, 11)

# %%
previously the rows were 2524 in total, now they are 2503

# %%
reset index

# %%
net.reset_index(drop = True)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0   15-01-22         10/6/2023
# 1         2.0           Premium             15.0   5/9/2021          22-06-23
# 2         3.0          Standard             12.0   28-02-23          27-06-23
# 3         4.0          Standard             12.0  10/7/2022          26-06-23
# 4         5.0             Basic             10.0   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2498   2500.0             Basic             15.0   13-08-22         12/7/2023
# 2499   2501.0             basic             15.0   13-08-22         12/7/2023
# 2500   2502.0           premium             13.0   18-07-22         11/7/2023
# 2501      NaN               NaN              NaN        NaN               NaN
# 2502      NaN               NaN              NaN        NaN               NaN
#
# ...

# %%
finding null values

# %%
net.isnull().sum()
#this generates only
# Out:
# User ID               2
# Subscription Type     2
# Monthly Revenue       4
# Join Date             2
# Last Payment Date     2
# Country               2
# Age                   3
# Gender                3
# Device                3
# Plan Duration         3
# not usefull          21
# dtype: int64

# %%
Using seaborn to visualize the nullvalues in the dataset

# %%
using seaborn to visualize the nullvalues in the dataset
import matplotlib.pyplot as plt
sns.heatmap(net.isnull())
plt.show()

# %%
removing a column we wont have need of

# %%
net.drop(columns = "not usefull", inplace=True)

# %%
net
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0   15-01-22         10/6/2023
# 1         2.0           Premium             15.0   5/9/2021          22-06-23
# 2         3.0          Standard             12.0   28-02-23          27-06-23
# 3         4.0          Standard             12.0  10/7/2022          26-06-23
# 4         5.0             Basic             10.0   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2499   2500.0             Basic             15.0   13-08-22         12/7/2023
# 2500   2501.0             basic             15.0   13-08-22         12/7/2023
# 2501   2502.0           premium             13.0   18-07-22         11/7/2023
# 2502      NaN               NaN              NaN        NaN               NaN
# 2503      NaN               NaN              NaN        NaN               NaN
#
# ...

# %%
removing unwanted records from our dataset

# %%
net["Country"] = net["Country"].str.strip("//...")
net.tail(25)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 2479   2480.0             Basic             13.0   7/8/2022          14-07-23
# 2480   2481.0           Premium             10.0   5/8/2022         12/7/2023
# 2481   2482.0          Standard             13.0   6/8/2022          14-07-23
# 2482   2483.0             Basic             15.0   28-07-22         11/7/2023
# 2483   2484.0          Standard             11.0   29-07-22          13-07-23
# 2484   2485.0           Premium             14.0   25-07-22         12/7/2023
# 2485   2486.0             Basic             10.0   25-07-22          14-07-23
# 2486   2487.0           Premium             11.0   25-07-22         12/7/2023
# 2487   2488.0          Standard             11.0   18-07-22          13-07-23
# 2488   2489.0             Basic             11.0   17-07-22         12/7/2023
# 2489   2490.0          Standard             10.0   17-07-22          15-07-23
# ...

# %%
using replace function to make correction on the Country column

# %%
net["Country"] = net["Country"].str.replace("the"," ")
net.tail(40)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 2463   2464.0          Standard             12.0  5/11/2022         12/7/2023
# 2464   2465.0             Basic             15.0  3/11/2022         11/7/2023
# 2465   2466.0           Premium             12.0   30-10-22          14-07-23
# 2466   2467.0             Basic             15.0   26-10-22         11/7/2023
# 2467   2468.0          Standard             14.0   24-10-22         12/7/2023
# 2468   2469.0           Premium             12.0   24-10-22         11/7/2023
# 2469   2470.0             Basic             13.0   20-10-22          13-07-23
# 2470   2471.0             Basic             10.0   17-10-22         11/7/2023
# 2471   2472.0             Basic             14.0   29-09-22          14-07-23
# 2472   2473.0          Standard             12.0   28-09-22         11/7/2023
# 2473   2474.0           Premium             10.0   6/9/2022         12/7/2023
# ...

# %%
checking for the no of unique values in the dataset

# %%
checking for the no of unique values in the dataset
net.nunique()
# Out:
# User ID              2501
# Subscription Type       5
# Monthly Revenue         6
# Join Date             300
# Last Payment Date      26
# Country                14
# Age                    26
# Gender                  3
# Device                  4
# Plan Duration           2
# dtype: int64

# %%
Dropping rows with all NaN values

# %%
net.dropna(how="all", inplace=True)
net
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0   15-01-22         10/6/2023
# 1         2.0           Premium             15.0   5/9/2021          22-06-23
# 2         3.0          Standard             12.0   28-02-23          27-06-23
# 3         4.0          Standard             12.0  10/7/2022          26-06-23
# 4         5.0             Basic             10.0   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2497   2498.0          Standard             12.0   9/8/2022          15-07-23
# 2498   2499.0          Standard             13.0  12/8/2022         12/7/2023
# 2499   2500.0             Basic             15.0   13-08-22         12/7/2023
# 2500   2501.0             basic             15.0   13-08-22         12/7/2023
# 2501   2502.0           premium             13.0   18-07-22         11/7/2023
#
# ...

# %%
net.dtypes
# Out:
# User ID              float64
# Subscription Type     object
# Monthly Revenue      float64
# Join Date             object
# Last Payment Date     object
# Country               object
# Age                  float64
# Gender                object
# Device                object
# Plan Duration         object
# dtype: object

# %%
Changing the last payment date dtype to datetime format

# %%
net['Last Payment Date']= pd.to_datetime(net['Last Payment Date'], format = 'mixed')

# %%
#verify
net.dtypes
# Out:
# User ID                     float64
# Subscription Type            object
# Monthly Revenue             float64
# Join Date                    object
# Last Payment Date    datetime64[ns]
# Country                      object
# Age                         float64
# Gender                       object
# Device                       object
# Plan Duration                object
# dtype: object

# %%
net
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0   15-01-22        2023-10-06
# 1         2.0           Premium             15.0   5/9/2021        2023-06-22
# 2         3.0          Standard             12.0   28-02-23        2023-06-27
# 3         4.0          Standard             12.0  10/7/2022        2023-06-26
# 4         5.0             Basic             10.0   1/5/2023        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2497   2498.0          Standard             12.0   9/8/2022        2023-07-15
# 2498   2499.0          Standard             13.0  12/8/2022        2023-12-07
# 2499   2500.0             Basic             15.0   13-08-22        2023-12-07
# 2500   2501.0             basic             15.0   13-08-22        2023-12-07
# 2501   2502.0           premium             13.0   18-07-22        2023-11-07
#
# ...

# %%
Changing the join Date column dtype to datetime format

# %%
net['Join Date']= pd.to_datetime(net['Join Date'], format = 'mixed')

# %%
#verify
net.dtypes
# Out:
# User ID                     float64
# Subscription Type            object
# Monthly Revenue             float64
# Join Date            datetime64[ns]
# Last Payment Date    datetime64[ns]
# Country                      object
# Age                         float64
# Gender                       object
# Device                       object
# Plan Duration                object
# dtype: object

# %%
net
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0 2022-01-15        2023-10-06
# 1         2.0           Premium             15.0 2021-05-09        2023-06-22
# 2         3.0          Standard             12.0 2023-02-28        2023-06-27
# 3         4.0          Standard             12.0 2022-10-07        2023-06-26
# 4         5.0             Basic             10.0 2023-01-05        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2497   2498.0          Standard             12.0 2022-09-08        2023-07-15
# 2498   2499.0          Standard             13.0 2022-12-08        2023-12-07
# 2499   2500.0             Basic             15.0 2022-08-13        2023-12-07
# 2500   2501.0             basic             15.0 2022-08-13        2023-12-07
# 2501   2502.0           premium             13.0 2022-07-18        2023-11-07
#
# ...

# %%
how many male subscribers are in the dataset

# %%
net[net["Gender"].isin(["Male"])]
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0 2022-01-15        2023-10-06
# 2         3.0          Standard             12.0 2023-02-28        2023-06-27
# 4         5.0             Basic             10.0 2023-01-05        2023-06-28
# 6         7.0          Standard             12.0 2021-09-12        2023-06-25
# 8         9.0          Standard             12.0 2022-10-20        2023-06-23
# ...       ...               ...              ...        ...               ...
# 2486   2487.0           Premium             11.0 2022-07-25        2023-12-07
# 2489   2490.0          Standard             10.0 2022-07-17        2023-07-15
# 2492   2493.0          Standard             11.0 2022-07-20        2023-11-07
# 2493   2494.0           Premium             12.0 2022-07-21        2023-07-15
# 2497   2498.0          Standard             12.0 2022-09-08        2023-07-15
#
# ...

# %%
How many users ever did standard and premium subscription

# %%
net[net["Subscription Type"].isin(["Standard","premium"])]
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 2         3.0          Standard             12.0 2023-02-28        2023-06-27
# 3         4.0          Standard             12.0 2022-10-07        2023-06-26
# 6         7.0          Standard             12.0 2021-09-12        2023-06-25
# 8         9.0          Standard             12.0 2022-10-20        2023-06-23
# 12       13.0          Standard             12.0 2021-11-30        2023-06-27
# ...       ...               ...              ...        ...               ...
# 2489   2490.0          Standard             10.0 2022-07-17        2023-07-15
# 2492   2493.0          Standard             11.0 2022-07-20        2023-11-07
# 2497   2498.0          Standard             12.0 2022-09-08        2023-07-15
# 2498   2499.0          Standard             13.0 2022-12-08        2023-12-07
# 2501   2502.0           premium             13.0 2022-07-18        2023-11-07
#
# ...

# %%
Find out the year with the highest no of subscribers

# %%
net['Join Date'].dt.year.value_counts()
# Out:
# Join Date
# 2022    2449
# 2023      38
# 2021      14
# Name: count, dtype: int64

# %%
using a Bar chart

# %%
net['Join Date'].dt.year.value_counts().plot(kind = 'bar', color = 'gray')
plt.title("frequency of release year", fontsize=20)
plt.xlabel("year", fontsize=15)
plt.ylabel("frequency", fontsize=15)
plt.show()

# %%
Total of each device used in the dataset

# %%
net.groupby('Device').Device.count()
# Out:
# Device
# Laptop        635
# Smart TV      610
# Smartphone    622
# Tablet        633
# Name: Device, dtype: int64

# %%
sns.countplot(net['Device'])
# Out:
# <Axes: xlabel='count', ylabel='Device'>

# %%
net.head()
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0      1.0             Basic             10.0 2022-01-15        2023-10-06
# 1      2.0           Premium             15.0 2021-05-09        2023-06-22
# 2      3.0          Standard             12.0 2023-02-28        2023-06-27
# 3      4.0          Standard             12.0 2022-10-07        2023-06-26
# 4      5.0             Basic             10.0 2023-01-05        2023-06-28
#
#           Country   Age  Gender      Device Plan Duration
# 0   United States  28.0    Male  Smartphone       1 Month
# 1          Canada  35.0  Female      Tablet       1 Month
# 2  United Kingdom  42.0    Male    Smart TV       1 Month
# 3       Australia  51.0  Female      Laptop       1 Month
# 4         Germany  33.0    Male  Smartphone       1 Month

# %%
 How many subscribers joined from germany in 2022

# %%
net['Years']= net['Join Date'].dt.year

# %%
Record of subscription from germany in 2022

# %%
net[(net['Country']== 'Germany') & (net['Years']== 2022)] #filtering
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 74       75.0             Basic             13.0 2022-05-28        2023-06-26
# 94       95.0             Basic             11.0 2022-02-28        2023-06-25
# 104     105.0             Basic             11.0 2022-04-03        2023-06-27
# 114     115.0             Basic             11.0 2022-05-04        2023-06-25
# 124     125.0             Basic             12.0 2022-08-21        2023-06-24
# ...       ...               ...              ...        ...               ...
# 2429   2430.0             Basic             10.0 2022-08-13        2023-11-07
# 2444   2445.0             Basic             14.0 2022-10-16        2023-10-07
# 2459   2460.0             Basic             15.0 2022-12-11        2023-07-13
# 2474   2475.0             Basic             12.0 2022-05-09        2023-11-07
# 2489   2490.0          Standard             10.0 2022-07-17        2023-07-15
#
# ...

# %%
net[(net['Country']== 'Germany') & (net['Gender']== 'Male')] ['Subscription Type'] #filtering Subscription type only
# Out:
# 4          Basic
# 94         Basic
# 124        Basic
# 154        Basic
# 164     Standard
#           ...
# 2354       Basic
# 2384       Basic
# 2399       Basic
# 2414    Standard
# 2489    Standard
# Name: Subscription Type, Length: 89, dtype: object

# %%
using value count function

# %%
net['Device'].value_counts().head(3)
# Out:
# Device
# Laptop        635
# Tablet        633
# Smartphone    622
# Name: count, dtype: int64

# %%
Plot the bar chart

# %%
plt.figure(figsize=(10,4))
net['Device'].value_counts().head(3).plot(kind='bar', color='Teal').set_title('Top 3 devices', fontsize=13)
plt.show()

# %%
net.head()
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0      1.0             Basic             10.0 2022-01-15        2023-10-06
# 1      2.0           Premium             15.0 2021-05-09        2023-06-22
# 2      3.0          Standard             12.0 2023-02-28        2023-06-27
# 3      4.0          Standard             12.0 2022-10-07        2023-06-26
# 4      5.0             Basic             10.0 2023-01-05        2023-06-28
#
#           Country   Age  Gender      Device Plan Duration  Years
# 0   United States  28.0    Male  Smartphone       1 Month   2022
# 1          Canada  35.0  Female      Tablet       1 Month   2021
# 2  United Kingdom  42.0    Male    Smart TV       1 Month   2023
# 3       Australia  51.0  Female      Laptop       1 Month   2022
# 4         Germany  33.0    Male  Smartphone       1 Month   2023

# %%
Showing data where country, gender and device columns are equal to canada, female and tablet

# %%
net[(net['Country']== 'Canada') & (net['Gender']== 'Female')& (net['Device']== 'Tablet')]
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 1         2.0           Premium             15.0 2021-05-09          22-06-23
# 151     152.0           Premium             14.0 2022-11-23          27-06-23
# 201     202.0             Basic             12.0 2022-06-26          27-06-23
# 261     262.0             Basic             12.0 2022-07-13          26-06-23
# 371     372.0             Basic             11.0 2022-06-09          27-06-23
# 421     422.0             Basic             14.0 2022-09-15          29-06-23
# 471     472.0             Basic             10.0 2022-07-13          27-06-23
# 506     507.0             Basic             15.0 2022-10-24          26-06-23
# 521     522.0             Basic             14.0 2022-06-17          27-06-23
# 551     552.0             Basic             13.0 2022-08-29          27-06-23
# 578     579.0          Standard             12.0 2022-10-16          28-06-23
# ...

# %%
How many subscribers opt for basic after 2021

# %%
net[(net['Subscription Type']== 'Basic') &(net['Years'] > 2021)]
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0         1.0             Basic             10.0 2022-01-15        2023-10-06
# 4         5.0             Basic             10.0 2023-01-05        2023-06-28
# 7         8.0             Basic             10.0 2023-02-04        2023-06-24
# 10       11.0             Basic             10.0 2022-05-16        2023-06-22
# 13       14.0             Basic             10.0 2022-01-08        2023-06-26
# ...       ...               ...              ...        ...               ...
# 2488   2489.0             Basic             11.0 2022-07-17        2023-12-07
# 2491   2492.0             Basic             14.0 2022-07-19        2023-12-07
# 2494   2495.0             Basic             15.0 2022-07-23        2023-12-07
# 2496   2497.0             Basic             15.0 2022-04-08        2023-07-14
# 2499   2500.0             Basic             15.0 2022-08-13        2023-12-07
#
# ...

# %%
Getting users with standard subscription only

# %%
net_data = net[net['Subscription Type']== 'Standard']

# %%
net_data.head()
# Out:
#     User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 2       3.0          Standard             12.0 2023-02-28        2023-06-27
# 3       4.0          Standard             12.0 2022-10-07        2023-06-26
# 6       7.0          Standard             12.0 2021-09-12        2023-06-25
# 8       9.0          Standard             12.0 2022-10-20        2023-06-23
# 12     13.0          Standard             12.0 2021-11-30        2023-06-27
#
#            Country   Age  Gender      Device Plan Duration  Years
# 2   United Kingdom  42.0    Male    Smart TV       1 Month   2023
# 3        Australia  51.0  Female      Laptop       1 Month   2022
# 6           Brazil  46.0    Male      Tablet       1 Month   2021
# 8            Spain  37.0    Male  Smartphone       1 Month   2022
# 12  United Kingdom  48.0  Female      Laptop       1 Month   2021

# %%
Which country has the highest no of subscribers

# %%
net_data['Country'].value_counts()
# Out:
# Country
# United Kingdom    180
# Mexico            179
# Spain             128
# United States     107
# Canada             83
# Australia          51
# Germany            31
# Brazil              4
# Italy               3
# Canada-             1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='Country', data=net, order=net['Country'].value_counts().index)
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.title("Top 5 most subscribed Countries", fontsize=15)
plt.show()

# %%
Sort the dataset by year

# %%
net.sort_values(by = 'Years').head(2)
# Out:
#     User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 17     18.0          Standard             12.0 2021-10-18        2023-06-24
# 22     23.0          Standard             12.0 2021-05-12        2023-06-27
#
#            Country   Age  Gender      Device Plan Duration  Years
# 17          Mexico  43.0    Male  Smartphone       1 Month   2021
# 22  United Kingdom  49.0  Female    Smart TV       1 Month   2021

# %%
net.sort_values(by = 'Years', ascending = False).head(2)
# Out:
#      User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 24      25.0             Basic             10.0 2023-03-14        2023-06-28
# 153    154.0          Standard             11.0 2023-11-03        2023-06-27
#
#        Country   Age  Gender  Device Plan Duration  Years
# 24     Germany  40.0  Female  Laptop       1 Month   2023
# 153  Australia  27.0    Male  Laptop       1 Month   2023
